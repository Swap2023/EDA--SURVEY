# %%
import pandas as pd

# %%
data=pd.read_csv(r"D:\STUDY\PYTHON\big data practice\backupdata\9. Survey.csv")

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
#1)1 - Load the dataset into a pandas dataframe. Name the variable as “survey”

# %%
survey=data

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
#2 - How many samples were collected on each day?

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
data.collection_date.value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
#3 - What proportion of the total respondents were aged less than 45?

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
data.age<45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 data.age<45
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
data.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
data.age.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
# ----> 1 data.age.astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
data.age.replace({'24ko':24},inplace=True)

# %%
data.age=data.age.astype(int)

# %%
data.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                   int32
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
#4 - Create a new column in the dataframe “age_group”. This column should contain the age 
#group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. 
#The dataframe should look like this after the column creation

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
data.insert(10,'agegroup', data.age.values )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 data.insert(10,'agegroup', data.age.values )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert agegroup, already exists

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
#18-25, 25-40, 40-55 and 55+.

# %%
data1=data[(data.age>18) & (data.age<25)]

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data2=data[(data.age>26) & (data.age<40)]

# %%
data2
# Out:
#       response_id collection_date urban_rural               education  \
# 1               2       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 5               6       5-24-2017       Urban                Graduate
# 6               7       5-24-2017       Urban                Graduate
# 7               8       5-24-2017       Rural  Professional Education
# ...           ...             ...         ...                     ...
# 6852         6853        6-1-2017       Rural                Graduate
# 6854         6855        6-1-2017       Rural       Post - Graduation
# 6855         6856        6-1-2017       Rural               12th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# ...

# %%
data2.agegroup='26-40 grp'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_8572\1749648550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.agegroup='26-40 grp'

# %%
data2
# Out:
#       response_id collection_date urban_rural               education  \
# 1               2       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 5               6       5-24-2017       Urban                Graduate
# 6               7       5-24-2017       Urban                Graduate
# 7               8       5-24-2017       Rural  Professional Education
# ...           ...             ...         ...                     ...
# 6852         6853        6-1-2017       Rural                Graduate
# 6854         6855        6-1-2017       Rural       Post - Graduation
# 6855         6856        6-1-2017       Rural               12th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# ...

# %%
data3=data[(data.age>41) & (data.age<55)]

# %%
data3.agegroup='41-55 grp'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_8572\701378701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.agegroup='41-55 grp'

# %%
data3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6810         6811        6-1-2017       Rural          12th Pass
# 6812         6813        6-1-2017       Rural          10th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# ...

# %%
data4=data[(data.age>56) & (data.age<100)]

# %%
data4.agegroup='56 plus'
# Out:
# C:\Users\Swapnil\AppData\Local\Temp\ipykernel_8572\1798215416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.agegroup='56 plus'

# %%
data4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# 282           283       5-24-2017       Urban                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
f_data=pd.concat([data1,data2,data3,data4])

# %%
f_data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
#How many samples were collected for each age-group? Which age-group had the most samples?

# %%
f_data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age   agegroup  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22  18-25 grp
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
f_data.groupby('agegroup').collection_date.value_counts()
# Out:
# agegroup   collection_date
# 18-25 grp  5-24-2017          371
#            5-25-2017          295
#            5-28-2017          221
#            5-27-2017          215
#            5-29-2017          190
#            5-26-2017          186
#            6-1-2017           181
#            5-30-2017          169
#            5-31-2017          141
# 26-40 grp  5-24-2017          671
#            5-25-2017          399
#            5-28-2017          329
#            5-31-2017          262
#            5-27-2017          253
#            6-1-2017           245
#            5-30-2017          241
#            5-29-2017          237
#            5-26-2017          220
# 41-55 grp  5-24-2017          145
#            5-25-2017           79
#            5-28-2017           62
#            5-29-2017           54
#            5-27-2017           53
#            5-30-2017           51
#            6-1-2017            50
#            5-26-2017           41
# ...

# %%
#What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions

# %%
f_data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age   agegroup  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22  18-25 grp
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
f_data[f_data.Vote_Now=='RJD']
# Out:
#       response_id collection_date urban_rural               education  \
# 16             17       5-24-2017       Rural       Post - Graduation
# 38             39       5-24-2017       Urban                Graduate
# 47             48       5-24-2017       Urban                Graduate
# 85             86       5-24-2017       Rural               12th Pass
# 107           108       5-24-2017       Urban               12th Pass
# ...           ...             ...         ...                     ...
# 5687         5688       5-29-2017       Urban                Graduate
# 5830         5831       5-30-2017       Urban                Graduate
# 6095         6096       5-24-2017       Rural                Graduate
# 6123         6124       5-24-2017       Urban  Professional Education
# 6579         6580       5-29-2017       Rural                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
f_data[f_data.Past_Vote	=='RJD']
# Out:
#       response_id collection_date urban_rural          education  \
# 16             17       5-24-2017       Rural  Post - Graduation
# 38             39       5-24-2017       Urban           Graduate
# 47             48       5-24-2017       Urban           Graduate
# 85             86       5-24-2017       Rural          12th Pass
# 120           121       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 4753         4754       5-26-2017       Rural  Post - Graduation
# 5493         5494       5-26-2017       Urban           Graduate
# 5687         5688       5-29-2017       Urban           Graduate
# 5700         5701       5-29-2017       Urban           Graduate
# 5830         5831       5-30-2017       Urban           Graduate
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# 16      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# ...

# %%
#For each day of sample collection, determine the proportion of respondents who were fully 
#satisfied with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied,
#then our answer for that day would be 0.3

# %%
f_data.head(1)
# Out:
#    response_id collection_date urban_rural education               income  \
# 4            5       5-24-2017       Rural  Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote  CM_satisfaction MLA_satisfaction  age   agegroup  \
# 4    JD(U)  Did not vote  Fully Satisfied  Fully Satisfied   22  18-25 grp
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505

# %%
f_data[f_data.CM_satisfaction=='Fully Satisfied']
# Out:
#       response_id collection_date urban_rural          education  \
# 4               5       5-24-2017       Rural           Graduate
# 8               9       5-24-2017       Urban          12th Pass
# 14             15       5-24-2017       Rural           Graduate
# 90             91       5-24-2017       Rural           Graduate
# 102           103       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 6341         6342       5-26-2017       Rural  Post - Graduation
# 6498         6499       5-28-2017       Urban  Post - Graduation
# 6513         6514       5-28-2017       Urban  Post - Graduation
# 6787         6788        6-1-2017       Rural          10th Pass
# 6851         6852        6-1-2017       Urban           Graduate
#
#                      income Vote_Now     Past_Vote  CM_satisfaction  \
# 4       ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote  Fully Satisfied
# ...

# %%
f_data[f_data.MLA_satisfaction=='Fully Dissatisfied']
# Out:
#       response_id collection_date urban_rural               education  \
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 18             19       5-24-2017       Rural                Graduate
# 47             48       5-24-2017       Urban                Graduate
# 49             50       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6123         6124       5-24-2017       Urban  Professional Education
# 6262         6263       5-25-2017       Urban                Graduate
# 6268         6269       5-25-2017       Rural                Graduate
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
#
#                      income Vote_Now Past_Vote        CM_satisfaction  \
# ...
